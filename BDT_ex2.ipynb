# %%
# Install Java
# !apt-get update -y
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null

# Download Hadoop 3.3.6
# !wget -q https://downloads.apache.org/hadoop/common/hadoop-3.3.6/hadoop-3.3.6.tar.gz
# !tar -xzf hadoop-3.3.6.tar.gz
# !mv hadoop-3.3.6 /usr/local/hadoop
# Out:
# Hit:1 https://cli.github.com/packages stable InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,085 kB]
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:10 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,812 kB]
# Hit:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:13 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:14 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,373 kB]
# Get:15 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,452 kB]
# Get:16 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,288 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,796 kB]
# Get:18 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [5,803 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [6,043 kB]
# Get:20 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd64 Packages [60.9 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,594 kB]
# Fetched 36.7 MB in 5s (7,251 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)

# %%
# Set environment variables
import os

os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["HADOOP_HOME"] = "/usr/local/hadoop"
os.environ["PATH"] = f"{os.environ['HADOOP_HOME']}/bin:{os.environ['JAVA_HOME']}/bin:" + os.environ["PATH"]

# !hadoop version
# Out:
# Hadoop 3.3.6
# Source code repository https://github.com/apache/hadoop.git -r 1be78238728da9266a4f88195058f08fd012bf9c
# Compiled by ubuntu on 2023-06-18T08:22Z
# Compiled on platform linux-x86_64
# Compiled with protoc 3.7.1
# From source with checksum 5652179ad55f76cb287d9c633bb53bbd
# This command was run using /usr/local/hadoop/share/hadoop/common/hadoop-common-3.3.6.jar

# %%
# %%bash
# cat > mapper.py <<'EOF'
# #!/usr/bin/env python3
# import sys
#
# # Input format: timestamp,temperature
# for line in sys.stdin:
#     line = line.strip()
#     if line:
#         parts = line.split(',')
#         date = parts[0].split()[0]  # extract date only
#         temp = int(parts[1])
#         print(f"{date}\t{temp}")
# EOF
#
# chmod +x mapper.py
# %%bash
# cat > combiner.py <<'EOF'
# #!/usr/bin/env python3
# import sys
# from collections import defaultdict
#
# temps = defaultdict(list)
#
# for line in sys.stdin:
#     date, temp = line.strip().split("\t")
#     temps[date].append(int(temp))
#
# for date, t_list in temps.items():
#     print(f"{date}\t{max(t_list)},{min(t_list)}")
# EOF
#
# chmod +x combiner.py
# Out:
# bash: line 16: fg: no job control

# %%
# %%bash
# cat > reducer.py <<'EOF'
# #!/usr/bin/env python3
# import sys
# from collections import defaultdict
#
# temps = defaultdict(list)
#
# for line in sys.stdin:
#     date, t_values = line.strip().split("\t")
#     max_temp, min_temp = map(int, t_values.split(','))
#     temps[date].append((max_temp, min_temp))
#
# for date, t_list in temps.items():
#     overall_max = max(t[0] for t in t_list)
#     overall_min = min(t[1] for t in t_list)
#     print(f"{date}\tMax: {overall_max}, Min: {overall_min}")
# EOF
#
# chmod +x reducer.py

# %%
# %%bash
# mkdir -p input
# cat > input/weather.csv <<EOF
# 2025-10-01 06:00,25
# 2025-10-01 12:00,30
# 2025-10-01 18:00,28
# 2025-10-02 06:00,24
# 2025-10-02 12:00,32
# 2025-10-02 18:00,29
# EOF

# %%
# !hdfs dfs -rm -r output
# Out:
# 2025-10-21 16:27:51,802 INFO Configuration.deprecation: io.bytes.per.checksum is deprecated. Instead, use dfs.bytes-per-checksum
# Deleted output

# %%
# !rm -rf output
# !hadoop jar /usr/local/hadoop/share/hadoop/tools/lib/hadoop-streaming-3.3.6.jar \
    -input input/weather.csv \
    -output output \
    -mapper mapper.py \
    -combiner combiner.py \
    -reducer reducer.py
# Out:
# 2025-10-21 16:28:12,002 INFO impl.MetricsConfig: Loaded properties from hadoop-metrics2.properties
# 2025-10-21 16:28:12,113 INFO impl.MetricsSystemImpl: Scheduled Metric snapshot period at 10 second(s).
# 2025-10-21 16:28:12,113 INFO impl.MetricsSystemImpl: JobTracker metrics system started
# 2025-10-21 16:28:12,137 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2025-10-21 16:28:12,430 INFO mapred.FileInputFormat: Total input files to process : 1
# 2025-10-21 16:28:12,454 INFO mapreduce.JobSubmitter: number of splits:1
# 2025-10-21 16:28:12,669 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_local2057063979_0001
# 2025-10-21 16:28:12,669 INFO mapreduce.JobSubmitter: Executing with tokens: []
# 2025-10-21 16:28:12,883 INFO mapreduce.Job: The url to track the job: http://localhost:8080/
# 2025-10-21 16:28:12,887 INFO mapreduce.Job: Running job: job_local2057063979_0001
# 2025-10-21 16:28:12,888 INFO mapred.LocalJobRunner: OutputCommitter set in config null
# 2025-10-21 16:28:12,892 INFO mapred.LocalJobRunner: OutputCommitter is org.apache.hadoop.mapred.FileOutputCommitter
# 2025-10-21 16:28:12,904 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2025-10-21 16:28:12,904 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2025-10-21 16:28:12,965 INFO mapred.LocalJobRunner: Waiting for map tasks
# 2025-10-21 16:28:12,968 INFO mapred.LocalJobRunner: Starting task: attempt_local2057063979_0001_m_000000_0
# 2025-10-21 16:28:13,008 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2025-10-21 16:28:13,008 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2025-10-21 16:28:13,044 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2025-10-21 16:28:13,060 INFO mapred.MapTask: Processing split: file:/content/input/weather.csv:0+120
# 2025-10-21 16:28:13,086 INFO mapred.MapTask: numReduceTasks: 1
# 2025-10-21 16:28:13,188 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2025-10-21 16:28:13,188 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2025-10-21 16:28:13,188 INFO mapred.MapTask: soft limit at 83886080
# 2025-10-21 16:28:13,188 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2025-10-21 16:28:13,188 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2025-10-21 16:28:13,195 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2025-10-21 16:28:13,202 INFO streaming.PipeMapRed: PipeMapRed exec [/content/./mapper.py]
# 2025-10-21 16:28:13,208 INFO Configuration.deprecation: mapred.work.output.dir is deprecated. Instead, use mapreduce.task.output.dir
# 2025-10-21 16:28:13,210 INFO Configuration.deprecation: mapred.local.dir is deprecated. Instead, use mapreduce.cluster.local.dir
# 2025-10-21 16:28:13,210 INFO Configuration.deprecation: map.input.file is deprecated. Instead, use mapreduce.map.input.file
# 2025-10-21 16:28:13,211 INFO Configuration.deprecation: map.input.length is deprecated. Instead, use mapreduce.map.input.length
# 2025-10-21 16:28:13,212 INFO Configuration.deprecation: mapred.job.id is deprecated. Instead, use mapreduce.job.id
# 2025-10-21 16:28:13,212 INFO Configuration.deprecation: mapred.task.partition is deprecated. Instead, use mapreduce.task.partition
# 2025-10-21 16:28:13,214 INFO Configuration.deprecation: map.input.start is deprecated. Instead, use mapreduce.map.input.start
# 2025-10-21 16:28:13,214 INFO Configuration.deprecation: mapred.task.is.map is deprecated. Instead, use mapreduce.task.ismap
# 2025-10-21 16:28:13,214 INFO Configuration.deprecation: mapred.task.id is deprecated. Instead, use mapreduce.task.attempt.id
# 2025-10-21 16:28:13,215 INFO Configuration.deprecation: mapred.tip.id is deprecated. Instead, use mapreduce.task.id
# 2025-10-21 16:28:13,215 INFO Configuration.deprecation: mapred.skip.on is deprecated. Instead, use mapreduce.job.skiprecords
# 2025-10-21 16:28:13,216 INFO Configuration.deprecation: user.name is deprecated. Instead, use mapreduce.job.user.name
# 2025-10-21 16:28:13,251 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2025-10-21 16:28:13,316 INFO streaming.PipeMapRed: Records R/W=6/1
# 2025-10-21 16:28:13,325 INFO streaming.PipeMapRed: MRErrorThread done
# 2025-10-21 16:28:13,325 INFO streaming.PipeMapRed: mapRedFinished
# 2025-10-21 16:28:13,329 INFO mapred.LocalJobRunner:
# 2025-10-21 16:28:13,329 INFO mapred.MapTask: Starting flush of map output
# 2025-10-21 16:28:13,329 INFO mapred.MapTask: Spilling map output
# 2025-10-21 16:28:13,329 INFO mapred.MapTask: bufstart = 0; bufend = 84; bufvoid = 104857600
# 2025-10-21 16:28:13,329 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 26214376(104857504); length = 21/6553600
# 2025-10-21 16:28:13,341 INFO streaming.PipeMapRed: PipeMapRed exec [/content/./combiner.py]
# 2025-10-21 16:28:13,345 INFO Configuration.deprecation: mapred.skip.map.auto.incr.proc.count is deprecated. Instead, use mapreduce.map.skip.proc-count.auto-incr
# 2025-10-21 16:28:13,365 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2025-10-21 16:28:13,451 INFO streaming.PipeMapRed: Records R/W=6/1
# 2025-10-21 16:28:13,468 INFO streaming.PipeMapRed: MRErrorThread done
# 2025-10-21 16:28:13,469 INFO streaming.PipeMapRed: mapRedFinished
# 2025-10-21 16:28:13,470 INFO mapred.MapTask: Finished spill 0
# 2025-10-21 16:28:13,518 INFO mapred.Task: Task:attempt_local2057063979_0001_m_000000_0 is done. And is in the process of committing
# 2025-10-21 16:28:13,521 INFO mapred.LocalJobRunner: Records R/W=6/1
# 2025-10-21 16:28:13,521 INFO mapred.Task: Task 'attempt_local2057063979_0001_m_000000_0' done.
# 2025-10-21 16:28:13,529 INFO mapred.Task: Final Counters for attempt_local2057063979_0001_m_000000_0: Counters: 18
# 	File System Counters
# 		FILE: Number of bytes read=141524
# 		FILE: Number of bytes written=784048
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=6
# 		Map output records=6
# 		Map output bytes=84
# 		Map output materialized bytes=44
# 		Input split bytes=83
# 		Combine input records=6
# 		Combine output records=2
# 		Spilled Records=2
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=20
# 		Total committed heap usage (bytes)=258473984
# 	File Input Format Counters
# 		Bytes Read=120
# 2025-10-21 16:28:13,529 INFO mapred.LocalJobRunner: Finishing task: attempt_local2057063979_0001_m_000000_0
# 2025-10-21 16:28:13,530 INFO mapred.LocalJobRunner: map task executor complete.
# 2025-10-21 16:28:13,535 INFO mapred.LocalJobRunner: Starting task: attempt_local2057063979_0001_r_000000_0
# 2025-10-21 16:28:13,535 INFO mapred.LocalJobRunner: Waiting for reduce tasks
# 2025-10-21 16:28:13,545 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2025-10-21 16:28:13,545 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2025-10-21 16:28:13,545 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2025-10-21 16:28:13,552 INFO mapred.ReduceTask: Using ShuffleConsumerPlugin: org.apache.hadoop.mapreduce.task.reduce.Shuffle@26c2fd46
# 2025-10-21 16:28:13,554 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2025-10-21 16:28:13,581 INFO reduce.MergeManagerImpl: MergerManager: memoryLimit=2116865152, maxSingleShuffleLimit=529216288, mergeThreshold=1397131008, ioSortFactor=10, memToMemMergeOutputsThreshold=10
# 2025-10-21 16:28:13,584 INFO reduce.EventFetcher: attempt_local2057063979_0001_r_000000_0 Thread started: EventFetcher for fetching Map Completion Events
# 2025-10-21 16:28:13,659 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local2057063979_0001_m_000000_0 decomp: 40 len: 44 to MEMORY
# 2025-10-21 16:28:13,666 INFO reduce.InMemoryMapOutput: Read 40 bytes from map-output for attempt_local2057063979_0001_m_000000_0
# 2025-10-21 16:28:13,669 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 40, inMemoryMapOutputs.size() -> 1, commitMemory -> 0, usedMemory ->40
# 2025-10-21 16:28:13,670 INFO reduce.EventFetcher: EventFetcher is interrupted.. Returning
# 2025-10-21 16:28:13,672 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 2025-10-21 16:28:13,672 INFO reduce.MergeManagerImpl: finalMerge called with 1 in-memory map-outputs and 0 on-disk map-outputs
# 2025-10-21 16:28:13,683 INFO mapred.Merger: Merging 1 sorted segments
# 2025-10-21 16:28:13,684 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 27 bytes
# 2025-10-21 16:28:13,685 INFO reduce.MergeManagerImpl: Merged 1 segments, 40 bytes to disk to satisfy reduce memory limit
# 2025-10-21 16:28:13,686 INFO reduce.MergeManagerImpl: Merging 1 files, 44 bytes from disk
# 2025-10-21 16:28:13,687 INFO reduce.MergeManagerImpl: Merging 0 segments, 0 bytes from memory into reduce
# 2025-10-21 16:28:13,687 INFO mapred.Merger: Merging 1 sorted segments
# 2025-10-21 16:28:13,688 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 27 bytes
# 2025-10-21 16:28:13,689 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 2025-10-21 16:28:13,694 INFO streaming.PipeMapRed: PipeMapRed exec [/content/./reducer.py]
# 2025-10-21 16:28:13,697 INFO Configuration.deprecation: mapred.job.tracker is deprecated. Instead, use mapreduce.jobtracker.address
# 2025-10-21 16:28:13,699 INFO Configuration.deprecation: mapred.map.tasks is deprecated. Instead, use mapreduce.job.maps
# 2025-10-21 16:28:13,719 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2025-10-21 16:28:13,782 INFO streaming.PipeMapRed: Records R/W=2/1
# 2025-10-21 16:28:13,793 INFO streaming.PipeMapRed: MRErrorThread done
# 2025-10-21 16:28:13,793 INFO streaming.PipeMapRed: mapRedFinished
# 2025-10-21 16:28:13,794 INFO mapred.Task: Task:attempt_local2057063979_0001_r_000000_0 is done. And is in the process of committing
# 2025-10-21 16:28:13,795 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 2025-10-21 16:28:13,796 INFO mapred.Task: Task attempt_local2057063979_0001_r_000000_0 is allowed to commit now
# 2025-10-21 16:28:13,797 INFO output.FileOutputCommitter: Saved output of task 'attempt_local2057063979_0001_r_000000_0' to file:/content/output
# 2025-10-21 16:28:13,801 INFO mapred.LocalJobRunner: Records R/W=2/1 > reduce
# 2025-10-21 16:28:13,801 INFO mapred.Task: Task 'attempt_local2057063979_0001_r_000000_0' done.
# 2025-10-21 16:28:13,802 INFO mapred.Task: Final Counters for attempt_local2057063979_0001_r_000000_0: Counters: 24
# 	File System Counters
# 		FILE: Number of bytes read=141644
# 		FILE: Number of bytes written=784160
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=2
# 		Reduce shuffle bytes=44
# 		Reduce input records=2
# 		Reduce output records=2
# 		Spilled Records=2
# 		Shuffled Maps =1
# 		Failed Shuffles=0
# 		Merged Map outputs=1
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=258473984
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Output Format Counters
# 		Bytes Written=68
# 2025-10-21 16:28:13,802 INFO mapred.LocalJobRunner: Finishing task: attempt_local2057063979_0001_r_000000_0
# 2025-10-21 16:28:13,802 INFO mapred.LocalJobRunner: reduce task executor complete.
# 2025-10-21 16:28:13,903 INFO mapreduce.Job: Job job_local2057063979_0001 running in uber mode : false
# 2025-10-21 16:28:13,904 INFO mapreduce.Job:  map 100% reduce 100%
# 2025-10-21 16:28:13,906 INFO mapreduce.Job: Job job_local2057063979_0001 completed successfully
# 2025-10-21 16:28:13,924 INFO mapreduce.Job: Counters: 30
# 	File System Counters
# 		FILE: Number of bytes read=283168
# 		FILE: Number of bytes written=1568208
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=6
# 		Map output records=6
# 		Map output bytes=84
# 		Map output materialized bytes=44
# 		Input split bytes=83
# 		Combine input records=6
# 		Combine output records=2
# 		Reduce input groups=2
# 		Reduce shuffle bytes=44
# 		Reduce input records=2
# 		Reduce output records=2
# 		Spilled Records=4
# 		Shuffled Maps =1
# 		Failed Shuffles=0
# 		Merged Map outputs=1
# 		GC time elapsed (ms)=20
# 		Total committed heap usage (bytes)=516947968
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=120
# 	File Output Format Counters
# 		Bytes Written=68
# 2025-10-21 16:28:13,926 INFO streaming.StreamJob: Output directory: output

# %%
# !cat output/part-00000
# Out:
# 2025-10-01	Max: 30, Min: 25
# 2025-10-02	Max: 32, Min: 24
